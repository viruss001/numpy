# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr1 = np.array([1,2,3,4,5])
arr2 = np.random.rand(3,3)
arr3 = np.zeros((3,3))

# %%
#save array in other file
np.save("array1.npy",arr1)
np.save("array2.npy",arr2)
np.save("array3.npy",arr3)

# %%
#load array from other file
loaded_array1 = np.load("array1.npy")
print(loaded_array1)
# Out:
# [1 2 3 4 5]

# %%
loaded_array2 = np.load("numpy-logo.npy")
print(loaded_array2)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
try :
    logo = np.load("numpy-logo.npy")
    #display
    plt.figure(figsize=(10,5))
    plt.subplot(121)
    plt.imshow(logo)
    plt.title("NUmpy Logo")
    dark_logo = 1-logo
    plt.subplot(122)
    plt.imshow(dark_logo)
    plt.title("NUmpy Dark Logo")

except FileNotFoundError:
    print("File Not found ")
